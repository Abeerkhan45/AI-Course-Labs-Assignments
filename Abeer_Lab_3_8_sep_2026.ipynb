# %% [markdown]
# <a href="https://colab.research.google.com/github/Abeerkhan45/AI-Course-Labs-Assignments/blob/main/Abeer_Lab_3_8_sep_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6Jcwaconr69mVkUmCV1jsTpL-sDlkWpQI8yqKNf0yb7yQ")


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Travel Agent Started (type 'exit' to stop)
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Agent:
#  Hello! Welcome to Pakistan Tourism. As your dedicated travel agent, I am thrilled to help you plan an unforgettable trip.
#
# For students looking for the perfect blend of jaw-dropping adventure, rich culture, safety, and budget-friendliness, there is no better destination than the crown jewel of the north: **Hunza Valley, Gilgit-Baltistan**.
#
# Here is your well-structured, student-friendly travel plan to Hunza Valley.
#
# ---
#
# ### 1. Destination Overview
# ...

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6Il2pENOQT9aV5MxYePej6yI4-M1UNzaU6mbDZtejFJWA")


MODEL = "models/gemini-3.5-flash"


def meetforge_agent(meeting_input):

    prompt = f"""
You are MeetForge, an intelligent meeting management and action-planning agent.

Analyze the following meeting conversation or transcript and convert it into organized, actionable information.

Provide a well-structured summary with clear headings:

1. Meeting Overview & Main Topics
2. Decisions Made
3. Action Plan (Include: Task, Responsible Person, Deadline, and Priority Level)
4. Unresolved Issues & Next Steps

Keep the output clear, precise, and easy for participants to understand.

Meeting Transcript/Input: {meeting_input}

Meeting Summary & Action Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("MeetForge Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = meetforge_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# MeetForge Agent Started (type 'exit' to stop)
#
# You: Hello
#
# Agent:
#  **MeetForge Meeting Summary & Action Plan**
#
# ### 1. Meeting Overview & Main Topics
# * **Overview:** The provided transcript contains only a brief greeting ("Hello"). No formal meeting topics, discussions, or presentations were recorded in this session.
#
# ### 2. Decisions Made
# * No decisions were made during this brief exchange.
#
# ### 3. Action Plan
# * No action items were identified.
#
# | Task | Responsible Person | Deadline | Priority Level |
# | :--- | :--- | :--- | :--- |
# | *N/A* | *N/A* | *N/A* | *N/A* |
#
# ### 4. Unresolved Issues & Next Steps
# * **Next Steps:** Please provide the full meeting transcript or notes. Once provided, MeetForge will analyze the complete discussion and generate a detailed summary, decision log, and actionable task list for your team.
#
# You: Wxit
#
# Agent:
#  Hello! I am **MeetForge**, your intelligent meeting management agent.
#
# ...
